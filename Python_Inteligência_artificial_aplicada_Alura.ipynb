# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusFarias15/Inteligencia_Artificial_Aplicada/blob/main/Python_Intelig%C3%AAncia_artificial_aplicada_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conectar a IA do Google com Python no Colab

# %%
from google.colab import userdata
import os
os.environ["GOOGLE_API_KEY"] = userdata.get('API_GEMINI')

# %%
from google import genai

client = genai.Client()

# %%
resposta = client.models.generate_content(model= "gemini-2.5-flash", contents= "Oii Gemini, testando conexão com sua API")
print(resposta.text)
# Out:
# Oii! 👋 Tudo certo por aqui! Sua mensagem chegou com sucesso, então parece que a conexão está funcionando perfeitamente.
#
# Como posso te ajudar?

# %%
chat = client.chats.create(model= "gemini-2.5-flash")

resposta = chat.send_message("Oii Gemini, testando conexão com sua API")

print(resposta.text)
# Out:
# Olá! Tudo certo por aqui! 👋
#
# Recebi sua mensagem perfeitamente. A conexão com minha API está funcionando bem.
#
# Como posso te ajudar hoje?

# %%
prompt = input("Digite sua pergunta: \n")

while prompt != "sair":
  resposta = chat.send_message(prompt)
  print(resposta.text)
  prompt = input("Digite sua pergunta: ")
  print("\n")
# Out:
# Digite sua pergunta:
# sair

# %%
email_bodies = [
    f"""
    Assunto: 🚨 Servidor em estado crítico

    Olá Time,

    Detectamos que o servidor *API-Gateway* está com uso de CPU acima de 95% nas últimas 2 horas.
    Ações sugeridas:
    - Verificar logs em /var/log/api
    - Avaliar necessidade de escalonamento automático
    - Reportar caso o problema persista

    Atenciosamente,
    Equipe de Monitoramento
    """,

    f"""
    Assunto: 🛠️ Janela de manutenção - Banco de Dados

    Prezados(as),

    Informamos que o banco de dados *DB-PROD* passará por manutenção preventiva no dia 28/09, das 02h00 às 04h00.
    Durante esse período, os serviços ficarão indisponíveis.

    Pedimos que programem suas atividades considerando essa parada.

    Obrigado,
    Time de Infraestrutura
    """
]

# %%
def resumidor_de_emails(lista_de_emails):
  for i, email in enumerate(lista_de_emails):
    resposta = client.models.generate_content(
      model="gemini-2.5-flash",
      contents=f"""Vou te mandar o corpo de um e-mail. Quero que você o resuma em apenas 1 linha,
                  passando o intuito daquele e-mail. Segue o e-mail: {email}"""
    )

    print(f"E-mail {i + 1}: {resposta.text}")
    print("-" * 50)

# %%
resumidor_de_emails(email_bodies)
# Out:
# E-mail 1: **Alerta crítico:** O servidor API-Gateway está com CPU acima de 95%, exigindo investigação imediata e ações.
# --------------------------------------------------
# E-mail 2: Aviso de manutenção preventiva no banco DB-PROD no dia 28/09 (02h-04h), com indisponibilidade de serviços.
# --------------------------------------------------

# %% [markdown]
# # Utilizando modelos LLM open source (GROQ)

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 5.9 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata
from groq import Groq

# Acessa a chave da API do Grok que você salvou como um Secret
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# Inicializa o cliente Groq sem passar a chave diretamente
client_groq = Groq()

completion = client_groq.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role": "user",
            "content": "Testando conexão com a API"
        }
    ],
    temperature=1,
    max_completion_tokens=8192,
    top_p=1,
    reasoning_effort="medium",
    stream=True,
    stop=None,
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# Conexão estabelecida com sucesso! A API está respondendo normalmente. Se precisar de algo mais, é só avisar.

# %% [markdown]
# # Desafio Alura - Python Inteligência e artificial aplicada:
#
# <br>
# 1. Criar um arquivo .txt a partir de uma lista de perguntas vindas de uma lista em Python [].
# <br>
# 2. Ler essa as perguntas desse arquivo .txt e salvá-las em uma lista Python
# <br>
# 3. Obter respostas de um LLM para cada uma.
# <br>
# 4. Salvar os resultados en um novo arquivo.csv
# <br>
# 5. Ler o arquivo.csv usando Pandas

# %%
import os
import pandas as pd
from google.colab import userdata
from groq import Groq

lista_desafio = []

with open("perguntas.txt", "r", encoding="utf-8") as arquivo:
    for linha in arquivo:
        if linha.strip():
            lista_desafio.append(linha.strip())

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")
client_groq = Groq()

lista_de_dicionarios_de_respostas = []

for pergunta in lista_desafio:
    completion = client_groq.chat.completions.create(
        model="openai/gpt-oss-20b",
        messages=[
            {"role": "user", "content": f"Responda de forma sucinta: {pergunta}"}
        ],
        temperature=0.3,
        max_completion_tokens=500,
        top_p=1,
    )

    resposta = completion.choices[0].message.content.strip()
    print(f"{resposta}\n")

    lista_de_dicionarios_de_respostas.append({
        "pergunta": pergunta,
        "resposta": resposta
    })

df_perguntas_e_respostas = pd.DataFrame(lista_de_dicionarios_de_respostas)
df_perguntas_e_respostas.to_csv("respostas.csv", index=False, encoding="utf-8")

df_perguntas_e_respostas = pd.read_csv("respostas.csv")
df_perguntas_e_respostas
# Out:
# Python é uma linguagem de programação de alto nível, interpretada e de propósito geral, conhecida por sua sintaxe clara e foco em produtividade e legibilidade.
#
# AWS (Amazon Web Services) é a plataforma de serviços de computação em nuvem da Amazon, oferecendo infraestrutura, armazenamento, banco de dados, inteligência artificial, e muito mais, tudo sob demanda e escalável.
#            pergunta                                           resposta
# 0  - O que é Python  Python é uma linguagem de programação de alto ...
# 1     - O que é AWS  AWS (Amazon Web Services) é a plataforma de se...

# %%
df_perguntas_e_respostas = pd.DataFrame(lista_de_dicionarios_de_respostas)
df_perguntas_e_respostas.to_csv("respostas.csv", index=False, encoding="utf-8")

df_perguntas_e_respostas = pd.read_csv("respostas.csv")
df_perguntas_e_respostas
# Out:
#            pergunta                                           resposta
# 0  - O que é Python  Python é uma linguagem de programação de alto ...
# 1     - O que é AWS  AWS (Amazon Web Services) é a plataforma de se...

# %% [markdown]
# # Pandas

# %%
import numpy as np

#Definindo os dados para as colunas

nomes_produtos = [f"Produto {i+1}" for i in range(50)]
categorias_produtos = np.random.choice(["Eletrônicos", "Livros", "Roupas", "Alimentos", "Brinquedos"], 50)
precos_produtos = np.random.uniform(10.0, 500.0, 50).round(2)
itens_vendidos = np.random.randint(1, 1000, 50)
avaliacoes_produtos = np.random.uniform (1.0, 5.0, 50).round(1)

#Criando o DataFrame

df_produtos = pd.DataFrame({
"Nome do produto": nomes_produtos,
"Categoria do produto": categorias_produtos,
"Preço do produto": precos_produtos,
"Itens vendidos": itens_vendidos,
"Avaliação do produto": avaliacoes_produtos
})


# Exibindo as primeiras linhas do DataFrame

df_produtos.head()
# Out:
#   Nome do produto Categoria do produto  Preço do produto  Itens vendidos  \
# 0       Produto 1               Livros            378.68              73
# 1       Produto 2          Eletrônicos            499.36             947
# 2       Produto 3               Livros            398.84             879
# 3       Produto 4               Roupas             64.09             549
# 4       Produto 5           Brinquedos            269.01             844
#
#    Avaliação do produto
# 0                   3.2
# 1                   1.8
# 2                   4.4
# 3                   2.7
# 4                   3.5

# %%
# N° de linhas e colunas

df_produtos.shape
# Out:
# (50, 5)

# %%
# Comparando duas colunas

df_produtos[(df_produtos["Categoria do produto"] == "Eletrônicos") & (df_produtos["Preço do produto"] >= 350.0)]
# Out:
#   Nome do produto Categoria do produto  Preço do produto  Itens vendidos  \
# 6       Produto 7          Eletrônicos            463.86             579
# 8       Produto 9          Eletrônicos            440.85             471
#
#    Avaliação do produto
# 6                   1.9
# 8                   1.6

# %%
# Retorna o produto na posição indicada
df_produtos.iloc[2]
# Out:
# Nome do produto         Produto 3
# Categoria do produto       Roupas
# Preço do produto           203.53
# Itens vendidos                803
# Avaliação do produto          3.2
# Name: 2, dtype: object

# %%
df_produtos_com_indice = df_produtos.set_index("Nome do produto")
df_produtos_com_indice.head()
# Out:
#                 Categoria do produto  Preço do produto  Itens vendidos  \
# Nome do produto
# Produto 1                     Roupas             94.55              90
# Produto 2                  Alimentos            193.97             834
# Produto 3                     Roupas            203.53             803
# Produto 4                     Roupas            441.66             507
# Produto 5                Eletrônicos            133.91             374
#
#                  Avaliação do produto
# Nome do produto
# Produto 1                         2.0
# Produto 2                         4.8
# Produto 3                         3.2
# Produto 4                         2.5
# Produto 5                         3.7

# %%
df_produtos_com_indice.loc["Produto 15":"Produto 35"]
# Out:
#                 Categoria do produto  Preço do produto  Itens vendidos  \
# Nome do produto
# Produto 15                    Livros            358.61             281
# Produto 16                 Alimentos            138.85             803
# Produto 17                    Roupas            265.25             784
# Produto 18                Brinquedos             97.12             487
# Produto 19                    Livros            425.16             378
# Produto 20                 Alimentos             85.33             602
# Produto 21                    Livros            476.54             440
# Produto 22                    Roupas             32.81              65
# Produto 23                    Roupas            357.09             361
# Produto 24                 Alimentos             19.20             434
# Produto 25                Brinquedos            217.54             148
# Produto 26               Eletrônicos             55.41             787
# ...

# %%
df_produtos_com_indice.loc[["Produto 45", "Produto 47", "Produto 16"], ["Preço do produto", "Itens vendidos"]]
# Out:
#                  Preço do produto  Itens vendidos
# Nome do produto
# Produto 45                 149.73             984
# Produto 47                 183.84             399
# Produto 16                 138.85             803

# %%
brinquedos = df_produtos_com_indice[df_produtos_com_indice["Categoria do produto"] == "Brinquedos"]
df_produtos_com_indice.loc[brinquedos.index, "Categoria do produto"] = "Infanto-juvenil"
df_produtos_com_indice['Categoria do produto'].unique()
# Out:
# array(['Roupas', 'Alimentos', 'Eletrônicos', 'Livros', 'Infanto-juvenil'],
#       dtype=object)

# %% [markdown]
# # Desafio - LLM + Classificador de satisfação:
#
# 1. Carregar um arquivo.csv com feedback de clientes (reviews.csv)
# 2. Usar um LLM para classificar o sentimento de cada feedback (Positivo, Negativo, Neutro)
# 3. Adicionar uma nova coluna com essa classificação ao DataFrame.

# %%
import pandas as pd
import numpy as np

# Gerando dados fictícios
num_linhas = 10
notas = np.random.randint(0, 6, num_linhas) # Notas de 0 a 5
nomes_produtos = [f"Produto_{i+1}" for i in range(num_linhas)]
tipos_produtos = np.random.choice(["Eletrônico", "Livro", "Roupa", "Alimento", "Brinquedo"], num_linhas)
categorias_produtos = np.random.choice(["Categoria A", "Categoria B", "Categoria C", "Categoria D"], num_linhas)

# Gerando depoimentos mais complexos e variados
depoimentos = []
for i in range(num_linhas):
    if notas[i] >= 4:
        depoimentos.append(f"Produto_{i+1} é excelente! Adorei a qualidade e o desempenho. Recomendo muito!") # Positivo
    elif notas[i] == 3:
        depoimentos.append(f"O Produto_{i+1} é razoável. Cumpre o que promete, mas não me surpreendeu. Nada de especial.") # Neutro
    else:
        depoimentos.append(f"Não gostei do Produto_{i+1}. A qualidade deixou a desejar e não atendeu às minhas expectativas. Decepcionado.") # Negativo

# Criando o DataFrame
df_reviews = pd.DataFrame({
    "Nota do produto": notas,
    "Nome do produto": nomes_produtos,
    "Tipo de produto": tipos_produtos,
    "Categoria do produto": categorias_produtos,
    "Depoimento do cliente": depoimentos
})

# Salvando em um arquivo CSV
df_reviews.to_csv("reviews.csv", index=False)

print("Arquivo 'reviews.csv' criado com sucesso com depoimentos mais variados!")
# Out:
# Arquivo 'reviews.csv' criado com sucesso com depoimentos mais variados!

# %%
df = pd.read_csv("reviews.csv")
df
# Out:
#    Nota do produto Nome do produto Tipo de produto Categoria do produto  \
# 0                2       Produto_1      Eletrônico          Categoria B
# 1                5       Produto_2        Alimento          Categoria D
# 2                0       Produto_3        Alimento          Categoria C
# 3                3       Produto_4           Roupa          Categoria C
# 4                0       Produto_5           Livro          Categoria B
# 5                1       Produto_6      Eletrônico          Categoria D
# 6                4       Produto_7        Alimento          Categoria D
# 7                1       Produto_8           Livro          Categoria B
# 8                3       Produto_9        Alimento          Categoria D
# 9                3      Produto_10           Livro          Categoria A
#
#                                Depoimento do cliente
# 0  Não gostei do Produto_1. A qualidade deixou a ...
# 1  Produto_2 é excelente! Adorei a qualidade e o ...
# ...

# %%
coluna_de_reviews = df_reviews["Depoimento do cliente"]

lista_de_analises_de_sentimentos = []

for review_numero, resenha in enumerate(coluna_de_reviews):
    resposta = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=f"""Você irá analisar a resenha que eu te mandarei abaixo, e retorna com uma análise de sentimento.
        Você deve responder APENAS com uma das seguintes palavras: 'Positiva', 'Negativa' ou 'Neutra',
        indicando o sentimento relativo aquela resenha específica.
        Exemplos:
        "Eu adorei esse produto" -> Positiva
        "Gostei, mas não é nada de especial" -> Neutra
        "Odiei esse produto" -> Negativa

        Segue a resenha a ser analisada: {resenha}
        """
    )
    lista_de_analises_de_sentimentos.append(resposta.text)
    print(f"Resenha {review_numero}: '{resenha}' -> Sentimento: {resposta.text}")

df_reviews["Análises de Sentimentos"] = lista_de_analises_de_sentimentos
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-1235874787.py in <cell line: 0>()
#       4
#       5 for review_numero, resenha in enumerate(coluna_de_reviews):
# ----> 6     resposta = client.models.generate_content(
#       7         model="gemini-2.5-flash",
#       8         contents=f"""Você irá analisar a resenha que eu te mandarei abaixo, e retorna com uma análise de sentimento.
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    6563     while remaining_remote_calls_afc > 0:
#    6564       i += 1
# -> 6565       response = self._generate_content(
#    6566           model=model, contents=contents, config=parsed_config
#    6567       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
# ...

# %%
df_reviews
# Out:
#    Nota do produto Nome do produto Tipo de produto Categoria do produto  \
# 0                2       Produto_1       Brinquedo          Categoria C
# 1                2       Produto_2      Eletrônico          Categoria D
# 2                5       Produto_3           Roupa          Categoria A
# 3                0       Produto_4           Roupa          Categoria A
# 4                0       Produto_5       Brinquedo          Categoria B
# 5                1       Produto_6           Roupa          Categoria C
# 6                1       Produto_7       Brinquedo          Categoria A
# 7                2       Produto_8       Brinquedo          Categoria A
# 8                4       Produto_9      Eletrônico          Categoria A
# 9                2      Produto_10           Roupa          Categoria A
#
#                                Depoimento do cliente
# 0  Não gostei do Produto_1. A qualidade deixou a ...
# 1  Não gostei do Produto_2. A qualidade deixou a ...
# ...
